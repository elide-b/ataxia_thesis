# %%
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt

data_path = './BOLD_TS/ag170913b_WT_tsc2_smoothed_n172.mat'

# %%
data = loadmat(data_path)

# %%
data = np.array(data['ag170913b_WT_tsc2_smoothed'])

# %%
plt.plot(data[:,171])
plt.show()
